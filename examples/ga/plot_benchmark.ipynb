# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns

# %%
knapsack = pd.read_csv('knapsack_benchmark.csv',delimiter=' ')

# %%
knapsack
# Out:
#       seconds  lambda          case
# 0    2.617375    1000    mkl_random
# 1    2.679619    1000    mkl_random
# 2    2.636859    1000    mkl_random
# 3    2.696431    1000    mkl_random
# 4   13.092051    5000    mkl_random
# 5   13.502090    5000    mkl_random
# 6   13.117044    5000    mkl_random
# 7   12.664680    5000    mkl_random
# 8   23.519865   10000    mkl_random
# 9   24.260731   10000    mkl_random
# 10  24.407573   10000    mkl_random
# 11  23.020647   10000    mkl_random
# 12   3.098340    1000  numpy_random
# 13   3.363593    1000  numpy_random
# 14   3.417606    1000  numpy_random
# 15   3.250609    1000  numpy_random
# 16  19.061482    5000  numpy_random
# 17  18.967168    5000  numpy_random
# 18  19.314832    5000  numpy_random
# 19  19.794241    5000  numpy_random
# 20  40.674991   10000  numpy_random
# 21  43.389444   10000  numpy_random
# 22  42.355941   10000  numpy_random
# 23  41.196596   10000  numpy_random
# 24   2.257737    1000          base
# ...

# %%
sns.set()
sns.lmplot('lambda', 'seconds', data=knapsack, hue='case', fit_reg=True)
plt.title("Intel MKL vs plain Numpy and base \nPython random module in Knapsack problem")
plt.show()
